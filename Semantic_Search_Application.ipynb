# %% [markdown]
# <a href="https://colab.research.google.com/github/kgarvita/MISC/blob/main/Semantic_Search_Application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semantic Search Complete Architecture
# 1. Search Types
# 2.Cosine and Dot product metric
# 3. Document Embedding techniques
# 4. FAISS storage and retrieval.
# 5. Synthetic Query Generation.
# 6. Bi-Encoder fine-tuning
# 7. Result Ranking

# %% [markdown]
# ### Symmetric Search
# Query and entries in the document is almost of same length and the document is small. for this cos product works well.
#
# Ex.
# Query: What is the capital of India?
# Document entry : Delhi is the capital of India.
#
#
# Model Details : https://www.sbert.net/docs/pretrained_models.html

# %% [markdown]
# ## Asymmetric Search
# When the document is big, dot product distance is calculated for search.
# Ex.
# Query: What are the big cities of India
# Document: All information about Delhi, Mumbai, ect.
# Model Details : https://www.sbert.net/docs/pretrained_models.html

# %% [markdown]
# ## Storage Options
# 1. Elastic Search
# 2. FAISS
# 3.Annoy
#
# Using FAISS as it is compatible with CPU/GPU

# %% [markdown]
# #Semantic Search application
# Steps:
# 1. Preprocess the data
# 2. Create embeddings
# 3. Create index and save it to FAISS vector store
# 4. Get the query from user
# 5. Summarize the query
# 6. Create query embedding
# 7. Perform search operation
# 8. Evaluate result
# 9. Return output

# %% [markdown]
# ## Code to create summary

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.2 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
summarizer = pipeline('summarization',
                      model="T5-small",

)
text = """ 1. I know SBO 9.3 PL07 can be installed on SAP HANA Platform Edition 1.0 SPS 12 Revision 122.27 (B1_for_SAP_HANA_Admin_Guide.pdf).

2. I follow the SAP HANA: Supported Operating Systems, it told me can be installed on SUSE 12 SP3

But my customer want to know exactly, is it possible install SBO9.3 PL07 for HANA on SUSE 12 SP5 or SUSE 15 SP2 ?"""

summarizer(text, max_length=100, do_sample = False)
# Out:
# ...
# [{'summary_text': 'I know SBO 9.3 PL07 can be installed on SAP HANA Platform Edition 1.0 SPS 12 Revision 122.27 (B1_for_SAP_HANA_Admin_Guide.pdf) but my customer want to know exactly, is it possible to install SBO9.3 for HANA on SUSE 12 SP5 or SUSE 15 SP2?'}]
